# %%
# !pip install --upgrade pip
# !pip install --upgrade transformers datasets[audio] accelerate evaluate jiwer
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: jiwer in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: datasets[audio] in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (0.70.15)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (0.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (0.11.0)
# Requirement already satisfied: soxr>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from datasets[audio]) (0.5.0.post1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (3.11.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.2.1)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /usr/local/lib/python3.11/dist-packages (from jiwer) (3.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->datasets[audio]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]) (2.22)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->datasets[audio]) (1.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->datasets[audio]) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->datasets[audio]) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->datasets[audio]) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets[audio]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets[audio]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets[audio]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets[audio]) (1.17.0)

# %%
from datasets import load_dataset
from huggingface_hub import notebook_login

import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline, SeamlessM4Tv2ForSpeechToText
from datasets import load_dataset, Audio

import evaluate
import jiwer # jiwer is the backend for the wer metric

cv_17 = load_dataset("mozilla-foundation/common_voice_17_0", "af", split="train")
# Out:
# README.md:   0%|          | 0.00/12.7k [00:00<?, ?B/s]
# common_voice_17_0.py:   0%|          | 0.00/8.19k [00:00<?, ?B/s]
# languages.py:   0%|          | 0.00/3.92k [00:00<?, ?B/s]
# release_stats.py:   0%|          | 0.00/132k [00:00<?, ?B/s]
# n_shards.json:   0%|          | 0.00/17.5k [00:00<?, ?B/s]
# af_train_0.tar:   0%|          | 0.00/2.98M [00:00<?, ?B/s]
# af_dev_0.tar:   0%|          | 0.00/2.29M [00:00<?, ?B/s]
# af_test_0.tar:   0%|          | 0.00/2.54M [00:00<?, ?B/s]
# af_other_0.tar:   0%|          | 0.00/502k [00:00<?, ?B/s]
# af_invalidated_0.tar:   0%|          | 0.00/4.23M [00:00<?, ?B/s]
# af_validated_0.tar:   0%|          | 0.00/7.80M [00:00<?, ?B/s]
# train.tsv:   0%|          | 0.00/27.3k [00:00<?, ?B/s]
# dev.tsv:   0%|          | 0.00/17.5k [00:00<?, ?B/s]
# test.tsv:   0%|          | 0.00/19.4k [00:00<?, ?B/s]
# other.tsv:   0%|          | 0.00/4.81k [00:00<?, ?B/s]
# invalidated.tsv:   0%|          | 0.00/63.7k [00:00<?, ?B/s]
# validated.tsv:   0%|          | 0.00/64.0k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 82it [00:00, 65686.20it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 54it [00:00, 25300.76it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 62it [00:00, 17638.67it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 15it [00:00, 36366.80it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 192it [00:00, 71424.07it/s]
# Generating validated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 198it [00:00, 65288.69it/s]

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)


processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
    generate_kwargs={"language": "af"}
)

prediction = []
actual = []

for x in cv_17:
  result = pipe(x["audio"])
  prediction.append(result["text"])
  actual.append(x["sentence"])
  print(x["sentence"])
  print(result["text"])
# Out:
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# You have passed language=af, but also have set `forced_decoder_ids` to [[1, None], [2, 50360]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of language=af.
# Vertraging in die aanstelling van diensverskaffers maak dit moeilik om projekte betyds te voltooi.
#  Vertraging om aanstelling van dienstverskaffers mag het moeilijk om projecte betijds te voltooi.
# Wat doen hy?
#  Wat doen hy?
# Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
#  Ons geniet altyd haar partijkies, want sy is een uitstekende gasvrouw.
# Taal is 'n belangrike instrument om begrip van menseregte en omgewingsgeregtigheid te ontwikkel.
#  Tal is een belangrike instrument om begrip van mensrechte en omgevingsgerechtigheid te ontwikkel.
# Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie?
#  Wat er van die volgende veiligheidsaspekt is, nie die verantwoordelikheid van die werknemer nie.
# Ek het monumente gesien
#  Ek het monument daar gesê.
# Hulle het matte nodig gehad om die kaal vloer te bedek.
#  Hul het matte nodig gehad om die koolvloer te bedek.
# Daar moet besef word dat die leeruitkomste saamwerk om leerders se taalvaardigheid te ontwikkel.
#  Daar moet besef word dat die leeruitkomste saamwerk om leders sy taalvaardigheid te ontwikkel.
# Die leerder moet kennis dra van verskillende beroepsmoontlikhede en die implikasies van keuses.
#  Die leraar moet kennis dra van verskillende beroepsmoedlikhede en die implikasies van keuzes.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Skryf die persentasie Facebook-gebruikers neer wat met behulp van mobiele toestelle ingeteken het.
#  Skryf die persentansie Facebook gebruikers neer wat met bol van mobiele toestelle ingeteken het.
# Daar is kritiek dat Somali's geteister word wanneer hulle sake by die polisiestasie aanmeld.
#  Daar is kritiek dat Somalis getuister word wanneer hulle zaken by die polisiestasie anmeld.
# Hy is nie so groen dat ’n koei hom sal vreet nie
#  Hy is nie so groen, dat ek koei hom sal vreed nie.
# Die Program van Assessering vir Besigheidstudies bestaan uit sewe take wat intern geassesseer word.
#  Die program van assesering vir bezigheidsstudies bestaan uit 7 take wat intern geasseseer word.
# Laai die vragmotor af.
#  Nooi, die vraag moet daar af.
# In noodgevalle sal die mediese noodbeampte die pasiënt na die gepaste mediese fasiliteit vervoer.
#  In noodgevallen sal die medische noodbeamte die patiënt na die gepaste medische faciliteit vervoer.
# Ek het vir ’n tyd Pools gestudeer
#  Ek het vir ee tyd Poels gestudeer.
# Daar is verskillende maniere om 'n argument- en 'n teenargument te struktureer.
#  Daar is verschillende maniere om argument en een teen-argument te structureer.
# Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het.
#  Verduidelik waarom Hitler die vernietiging van die jode as die belangrikse taak beskou het.
# Die ingrypings is deel van die Program vir Grondhervorming en Geïntegreerde Steun vir Boere.
#  Die ingrijpings is deel van die program vir grondhervorming en geïntegreerde steen vir boere.
# Hy het baie struikelblokke teëgekom op pad om sy doelwitte te bereik.
#  Hy baie struikelblokke tegenkom op pad om sy doelwitte te bereik.
# Vergeet van die verlede.
#  Vergeet van die verlede.
# Informele of daaglikse assessering behels die daaglikse monitering van die leerders se vordering.
#  Informele of dagelikse assesering beheld die dagelikse monitoring van die leder se vordering.
# Sy het gesteun toe sy die swaar pot oplig.
#  Sy het gesteend, toe sy die swaarboot oplag.
# Alle biblioteke word deur die Landelike Biblioteekkonnektiwiteit-projek aan die Internet verbind.
#  Alle bibliotheke word in die landelike bibliotheekonektiviteitprojek aan die internet verbind.
# Ek kannie môre praat nie
#  Ek kan nie moorde praat nie.
# Nou en dan las sy vrou ’n woord tussen.
#  Nou en dan laat sy vrou een woord tussen.
# Is die inligting betroubaar?
#  Is die inlichting betrouwbaar?
# Die regering beskou ook marikultuur as belangrik omdat die mariene bronne aangevul moet word.
#  Die regering beskou ook marikultuur as belangrik, omdat die marinebronne aangevormd moet word.
# Hierdie vennootskap het buitengewone positiewe resultate gelewer, wat verbruikers bevoordeel het.
#  Hierdie vernooskap het buitengewone positieve resultate gelever wat verbruiker bevoordeel het.
# Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word.
#  Die eigenskap van elke forum word aangeleer voordat vergelykings tussen forums bespreek kan word.
# Hy het sy kakebeen in 'n bakleiery gebreek.
#  Hy het sy kakebeen in die beklaai raai gebreek.
# Die verkoopsyfers van twee motorvervaardigers in Suid-Afrika vir 'n sesmaande-tydperk is vrygestel.
#  Die verkoopcijfers van twee motorvervaardigers in Zuid-Afrika vir een 6-mane-tijdberg is vrygestel.
# Ons gaan in die vakansie na 'n wildreservaat toe.
#  Ons gaan in vakantie na een wild reservoir toe.
# Wanneer is jou vrou se verjaarsdag?
#  Wanneer is jou vrou sy verjaarsdag?
# Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande.
#  Beplanning is een dynamische proces wat voorsiening maak vir aanpassing as gevolg van toestande.
# Maak die leerders deurgaans van die gebruik van hoofletters, spasiëring en leestekens bewus.
#  Maak die leerders doorgaans van die gebruik van hoofletters, spasiering en leestekens bewus.
# Beskryf die tipe gesteente en onderliggende struktuur wat met dreineerpatroon C geassosieer word.
#  Beskryf die type gesteente en onderliggende struktuur wat met reineerpatroon C geassocieer word.
# My bejaarde buurvrou is 'n weduwee.
#  My bejaarde biervrou is een weduwee.
# Getal subsidies wat na naskoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf.
#  Getal subsidies wat na naskoelse sorgfasiliteite oorgedra is om dienste aan kinders te verskaaf.
# Ek kan beter asemhaal as die lug skoon is.
#  Ek kan beter asemhal as die lucht skoen is.
# Ek eet dikwels smiddae vis
#  Ek eet Dikwels Smidoffers.
# In Eendekuil het een deelnemer vir meer motorfietse vir patrollies in landelike gebiede gevra.
#  In Eendekuil het een deelnemer vir meer motorfietsen vir patrolies in landelike gebiede gevra.
# Energiebesparende busse word tans gebruik om mense na en van die besienswaardigheid te vervoer.
#  Energiebesparende busse word thans gebruik om mense na en van die besienswaardigheid te vervoer.
# Vergroot hierdie foto en sit dit op die muur.
#  Vergroot hier die foto en sit dit op die meer.
# Dit stel leerders in staat om sirkels en vierkante in verskillende posisies te identifiseer.
#  Dit stel leerders in staat om cirkels en vierkante in verskillende posiesies te identificeer.
# Hy hou baie daarvan om sport te beoefen
#  Hy hou baie daarvan om sport te beoefen.
# Hy geniet alkoholiese drankies, soos bier en wyn.
#  Hy geniet alkoolise drankies soos bier en wijn.
# Verbeterde funksionering van munisipale infrastruktuur en toegang tot basiese dienste aan inwoners.
#  Verbeter de functionering van municipale infrastructuur en toegang tot basisdienste aan inwoner.
# Dit is my broer
#  Dit is my broer.
# Tweedens gee die gewigsaanduiding riglyne om die inhoud van assessering eweredig te versprei.
#  Tweedens gee die gewigsanduiding rugleine om die inhoud van assessering evenredig te verspreid.
# Dis algaar dinge voor ons tyd, waarmee ons nou niks te doen het nie.
#  Dis al gaar dinge voor ons tyd, waarmee ons nou niks te doen het neem.
# Sodra hierdie hoërisikogesinne gestabiliseer is, sal die fokus na mediumrisikogevalle verskuif.
#  Sodra hierdie hoge risiko gesinne gestabiliseer is, sal die focus na medium risiko gevalle verskuif.
# Soos wat die wêreldbevolking gegroei het, het die aanvraag na stikstofryke kunsmis toegeneem.
#  Soos wat die wereldbevolking gegroe het, het die aanvraag na stikstofreike kunstmis toegeneem.
# Hier las sy vrou ’n woordjie in en sê: “Julle moet verstaan".
#  Hier las sy vrou een woorkie in en sê, jylle moet verstaan.
# Leer my asseblief hoe om naaldwerk te doen sodat ek klere kan maak.
#  Leer my asseblief hoe om noodwerk te doen, so dat ek kleren kan maak.
# Nogtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat 'n Landswapen vereis.
#  Nochtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat die landswapen vereis.
# Daar word vertrou dat alle belanghebbendes die inhoud as vernuwend en interessant sal ervaar.
#  Daar wordt vertrouw dat alle belanghebendes die inhoud as vernieuwend en interessant sal ervaar.
# Iemand die ore van die kop praat
#  Iemand die oore van die kop praat.
# Wat het jy gisteraand vir aandete geëet?
#  Wat het jy gister aand vir aandete geeet?
# Gevolglik ontstaan genotipiese en fenotipiese verskille met verloop van tyd tussen die bevolkings.
#  Gevolglik ontstaan genotypise en phenotypise verskille met die verloop van tyd tussen die bevolkings.
# Ons sal die bul kastreer as hy 'n jaar oud is.
#  Ons sal die bul kastreer as hy een jaar oud is.
# Skoonmaak- en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslewering te verseker.
#  Skoonmaak en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslevering te verseker.
# Iemand in die rug steek
#  Iemand in die rug steek
# Kom ons kyk na die beginsels van verwysings.
#  Kom ons kyk na die beginsels van verwysings.
# Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede.
#  Armoede is die duidelikste sigtbaar in landelike gebiede weens die gebrek aan werksgeleendhede.
# Ons moet nou aandete voorberei sodat dit betyds gereed is.
#  Ons moet nou ont eten voorbereid so dat dit betijds gereed is.
# Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
#  Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
# Benoemings moet ingedien word deur die Amptelike Benoemingsvorm by hierdie Kennisgewing te gebruik.
#  Benoemings moet ingedien word dier die amtelike benoemingsvorm by hier die kennisgeving te gebruik.
# Hulle staan soggens vroeg op
#  Hylle staan sogens vroeg op.
# Dit is 'n stil nag.
#  Dit is Stolnach.
# Gebruik die gegewe inligting om 'n frekwensietabel van die verskillende dromme afval te teken.
#  Gebruik die gegeven inlichting om een frekwensietabel van die verskillende droma afval te teken.
# Haar wange is bloesend.
#  Horwange is bloesend.
# Die kamer is leeg - daar is niemand daar nie.
#  Die kamer is leeg, daar is niemand daar nie.
# Dit ondersteun ook ekonomiese groei om die skep van broodnodige werksgeleenthede te bevorder.
#  Dit ondersteun ook economische groei om die skip van broodnodige werksgeleendheid te bevorder.
# Ons het die groot skoffel gebruik om die hardnekkige onkruid uit te grawe.
#  Ons het die groot skoffel gebruik om die hardnekkige onkruid uit te grawe.
# Vir vertaal- en tolkdoeleindes ontstaan daar nuwe velde waarvoor voorskrifte tans nie bestaan nie.
#  Vertaal en toekvlo eindes ontstaan daar nieuwe velde waarvoor voorschrifte thans nie bestaan.
# Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëernaalde oorgedra word.
#  Dit kan onder meer ook dier die gebruik van ongesteriliseerde tattooeernolde oorgedra word.
# Gooi asseblief al die rommel in die vullisblik.
#  Gooi asseblief al die rommel in die villesblik.
# Die besoeke sal hoofsaaklik fokus op die versterking van bilaterale verhoudinge met albei lande.
#  Die besuke sal oorsakelik focus op die versterking van bilaterale verhoudinge met albelande.
# Hy sê vervalste goedere verlam die plaaslike vervaardigers in die klere- en die tekstielsektor.
#  Hy sê vervalste goedere verland die plaaslike vervaardigers in die kleren en die tekstielsektor.
# Die laaste aspek wat jy moet oorweeg, is betrokkenheid.
#  Die laaste aspek wat jy moet oorweeg is betrokkenheid.
# Ek het laasweek met ’n nuwe werk begin
#  Ek het laasweek met een nieuwe werk begin.

# %%
wer_metric = evaluate.load("wer")
overall_wer = wer_metric.compute(predictions=prediction, references=actual)

print(f"\n--- Evaluation Complete ---")
print(f"Evaluated on {len(prediction)} samples.")
print(f"Overall Word Error Rate (WER): {overall_wer:.4f}")
print(f"(Lower WER is better. 0 indicates perfect transcription.)")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# --- Evaluation Complete ---
# Evaluated on 82 samples.
# Overall Word Error Rate (WER): 0.3038
# (Lower WER is better. 0 indicates perfect transcription.)

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-small"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)


processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
    generate_kwargs={"language": "af"}
)

prediction = []
actual = []

for x in cv_17:
  result = pipe(x["audio"])
  prediction.append(result["text"])
  actual.append(x["sentence"])
  print(x["sentence"])
  print(result["text"])
# Out:
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.87k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# Device set to use cuda:0
# You have passed language=af, but also have set `forced_decoder_ids` to [[1, None], [2, 50359]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of language=af.
# Vertraging in die aanstelling van diensverskaffers maak dit moeilik om projekte betyds te voltooi.
#  Betroging aan saling van diensfischkafers mogen mulegoem projecten beteidste voldooi.
# Wat doen hy?
#  Button high.
# Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
#  Ons geniet al het hore partaag is ons zeis dat het is teken in gas voor jou.
# Taal is 'n belangrike instrument om begrip van menseregte en omgewingsgeregtigheid te ontwikkel.
#  Taal is een belangrijke instrument om begriep van mensenraag te in omgevens gereaagdigheid te ontwakkel.
# Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie?
#  Water van die volgende veiligheidsaspect is nie die framwoordelijkheid van die waard nemer nie.
# Ek het monumente gesien
#  Ek het monumente gesie.
# Hulle het matte nodig gehad om die kaal vloer te bedek.
#  Hel het matten door de groot om die koolvloer te bedaak.
# Daar moet besef word dat die leeruitkomste saamwerk om leerders se taalvaardigheid te ontwikkel.
#  Toor moet besewoord dat die leerheidkomse zonberg ondedeersse talvaardigheid te ontwekkel.
# Die leerder moet kennis dra van verskillende beroepsmoontlikhede en die implikasies van keuses.
#  De leerder moet kennis draa van verschillende beroepsmoodlikkeren en die implicaties van keuses.
# Skryf die persentasie Facebook-gebruikers neer wat met behulp van mobiele toestelle ingeteken het.
#  Schrijf die patientancy Facebook gebruikers neer wat met bol van mobiele toestellen in getekenheid.
# Daar is kritiek dat Somali's geteister word wanneer hulle sake by die polisiestasie aanmeld.
#  Toor is kritiek dat zo mool is, had tijsterwoord van herersoog op die politie stoosie onmeld.
# Hy is nie so groen dat ’n koei hom sal vreet nie
#  Hij is nie zo grun dat de koei hong zal vrije neen.
# Die Program van Assessering vir Besigheidstudies bestaan uit sewe take wat intern geassesseer word.
#  De program van Assessering verbesigheid studies bestaan uit 7 taken wat intern ge-assessierwoord.
# Laai die vragmotor af.
#  Nooi, die vroeg moot daaraf.
# In noodgevalle sal die mediese noodbeampte die pasiënt na die gepaste mediese fasiliteit vervoer.
#  In het geval is het die mirrisbeamte die pascheen na die kapasten mirris de faciliteiten vervoer.
# Ek het vir ’n tyd Pools gestudeer
#  Ik heb ver het tijd pols gestudeer.
# Daar is verskillende maniere om 'n argument- en 'n teenargument te struktureer.
#  Door is verschriene manieren om archiemeent in het deen archiemeent destructurier.
# Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het.
#  Verdaeilijk waarom Hitler die vernetiging van die joden as die belangrijkste taak beskouwit.
# Die ingrypings is deel van die Program vir Grondhervorming en Geïntegreerde Steun vir Boere.
#  Die engrijpingsdeel van die program vergoond hervorming in geintegrere steen verburen.
# Hy het baie struikelblokke teëgekom op pad om sy doelwitte te bereik.
#  Hei, bae, strijko, blok, dieg, akum opbaat, umse duwende te bereik.
# Vergeet van die verlede.
#  Vergeet van die verleden.
# Informele of daaglikse assessering behels die daaglikse monitering van die leerders se vordering.
#  en formelen of dagelijks associering bij al die dagelijks in monitoring van die leder ze vooderen.
# Sy het gesteun toe sy die swaar pot oplig.
#  Zij het gestien tussen die zwaarboot oplach.
# Alle biblioteke word deur die Landelike Biblioteekkonnektiwiteit-projek aan die Internet verbind.
#  Aan die bibliotheek, woordie die lande, die bibliotheek ondiekt, die weet, die prijek, aan die internet verbend.
# Ek kannie môre praat nie
#  Akk nie moore praat nie.
# Nou en dan las sy vrou ’n woord tussen.
#  Nu en dan las ek vrouw afwoord te sinne.
# Is die inligting betroubaar?
#  Is die inlachting betrouwboor?
# Die regering beskou ook marikultuur as belangrik omdat die mariene bronne aangevul moet word.
#  De regering beskouw ik marrikultier als belangrijk na die marinebronen aangevormd wordt.
# Hierdie vennootskap het buitengewone positiewe resultate gelewer, wat verbruikers bevoordeel het.
#  Hierdie verneuws kap het bijten gewone poeder die weer resultaal te gelever, wat verbreiker bevoerdeel heet.
# Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word.
#  Die einskappen van alke vorm wordt aangeleer voor het vergelijkingsdus in vorms bespreken word.
# Hy het sy kakebeen in 'n bakleiery gebreek.
#  Het is kokenbien in de bekleirij gebreek.
# Die verkoopsyfers van twee motorvervaardigers in Suid-Afrika vir 'n sesmaande-tydperk is vrygestel.
#  Die verkubcijfers van 2 moedervervolgers in Zuid-Afrika verhezees monen tijdberg is vrijgestel.
# Ons gaan in die vakansie na 'n wildreservaat toe.
#  Ons gaan in het vakantie nou een woelt reserfoto.
# Wanneer is jou vrou se verjaarsdag?
#  Wanneer is je vrouwse van je horstdag?
# Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande.
#  Beplanning is het dynamische proces wat voorziening maak veranpassing als gevolg van toestanden.
# Maak die leerders deurgaans van die gebruik van hoofletters, spasiëring en leestekens bewus.
#  Maak die leerder dier gaans van die gebruik van wufletters, spassiering en leesdekensbeweus.
# Beskryf die tipe gesteente en onderliggende struktuur wat met dreineerpatroon C geassosieer word.
#  Beskrijf die type gesteente en onderlagende structuur wat met traineerpatroon sie geassocieer wordt.
# My bejaarde buurvrou is 'n weduwee.
#  Mijn bejaarde bierfrou is een veriewe.
# Getal subsidies wat na naskoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf.
#  Ketal syp sedies wat na na schoolse sorffaciliteiten oor gedrawe is om dienste aan keners te verskaar.
# Ek kan beter asemhaal as die lug skoon is.
#  Ek kan bedder osmol as die lucht scoren is.
# Ek eet dikwels smiddae vis
#  Ek eet Dukfels smid office.
# In Eendekuil het een deelnemer vir meer motorfietse vir patrollies in landelike gebiede gevra.
#  In Eende Kooil heet Eendeel nemer vermeer motorfietsen, verpatrolies en landelijke gebieden gevroo.
# Energiebesparende busse word tans gebruik om mense na en van die besienswaardigheid te vervoer.
#  In ergiebesparende bussen wordt dansgebruik om mensen na in van die besienswaardigheid te vervoer.
# Vergroot hierdie foto en sit dit op die muur.
#  Vergroeid hier die foto en zit het op die meer.
# Dit stel leerders in staat om sirkels en vierkante in verskillende posisies te identifiseer.
#  De stal leerder is in staat om cirkels en vier kanten in verschillende posities te identifiseren.
# Hy hou baie daarvan om sport te beoefen
#  I have buy it orphan on sport the boven.
# Hy geniet alkoholiese drankies, soos bier en wyn.
#  Hij geniet alke willyse drankis, dus bier in wijn.
# Verbeterde funksionering van munisipale infrastruktuur en toegang tot basiese dienste aan inwoners.
#  verbeter de functionering van municipale infrastructuur in toegang tot basisendienste aan en woner.
# Dit is my broer
#  Dit is m'n broer.
# Tweedens gee die gewigsaanduiding riglyne om die inhoud van assessering eweredig te versprei.
#  Twirrens geer die gewichtsandaiding ruglijnen om die inhoud van assysiering ieverredeig te versprei.
# Dis algaar dinge voor ons tyd, waarmee ons nou niks te doen het nie.
#  Dys al gaar dingen voor ons tijd, waarmee ons nou niks te doen heet nie.
# Sodra hierdie hoërisikogesinne gestabiliseer is, sal die fokus na mediumrisikogevalle verskuif.
#  Zou het draa hierdie uur risiekooges in en gestabilisier is, zal die fukes nou medium risiekooges vallen verskoos.
# Soos wat die wêreldbevolking gegroei het, het die aanvraag na stikstofryke kunsmis toegeneem.
#  Sos waar die wereldbevolkling gegroeid heet die aanvraag met stikstof rijke kunstmis toegeneem.
# Hier las sy vrou ’n woordjie in en sê: “Julle moet verstaan".
#  Hier laat zich vrouwe woerke in en zei, je moet verstaan.
# Leer my asseblief hoe om naaldwerk te doen sodat ek klere kan maak.
#  Ler mij as het bleef hoe om nolt ver te doen, zodat ek klere kan maak.
# Nogtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat 'n Landswapen vereis.
#  Noochtans behouder duidelig destabiliteit, stemmigheid en dringendheid van de landswopen vereis.
# Daar word vertrou dat alle belanghebbendes die inhoud as vernuwend en interessant sal ervaar.
#  daar wordt vertrouw dat alle belanghebendes die inuit als vernievend en interessant zal ervoor.
# Iemand die ore van die kop praat
#  Iemand die ure van die kop proot.
# Wat het jy gisteraand vir aandete geëet?
#  Wat het jy gister aan veraant eten geët?
# Gevolglik ontstaan genotipiese en fenotipiese verskille met verloop van tyd tussen die bevolkings.
#  Gevolgelijk ontstaan genutipissen en finutipissen verskelen met die verloop van tijd des in die bevolkings.
# Ons sal die bul kastreer as hy 'n jaar oud is.
#  en zal die bulkastryer als aie jor oud is.
# Skoonmaak- en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslewering te verseker.
#  Schoenmark en Securiteitsdienste is uitgekontrakteer om verbeterde dienstlevering te versieker.
# Iemand in die rug steek
#  Iemand in die roogstiek.
# Kom ons kyk na die beginsels van verwysings.
#  Kom ons kijk na die begrensels van verwijsames.
# Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede.
#  Ar en muda is die duidelijkste zichtbaar in landelijke gebieden wie ons die gebraak aan werksgeleendeerde.
# Ons moet nou aandete voorberei sodat dit betyds gereed is.
#  ons moet nou oond in de voorbrijs zodat dit de tijds gereed is.
# Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
#  De leerder verdaeilijk vague waag hoe improvisering kan help in die voorbereiding van choreografie.
# Benoemings moet ingedien word deur die Amptelike Benoemingsvorm by hierdie Kennisgewing te gebruik.
#  Benummings moet ingedienwoord hier die aantelijke benummingsvorm bij hier die kennisgeving te gebruik.
# Hulle staan soggens vroeg op
#  Halistan sohens vrych op.
# Dit is 'n stil nag.
#  Dit is stoonnag.
# Gebruik die gegewe inligting om 'n frekwensietabel van die verskillende dromme afval te teken.
#  Gebruik die gegeven en lachting wat frequentie tabel van die verschillende dromen afval te dikken.
# Haar wange is bloesend.
#  Horvange is blusend.
# Die kamer is leeg - daar is niemand daar nie.
#  Die kamer is leeg, daar is niemand daar nie.
# Dit ondersteun ook ekonomiese groei om die skep van broodnodige werksgeleenthede te bevorder.
#  dit ondarsteen ook ik genoem is ek groei om die schip van broodnore gewerks geleen te dit te bevorder.
# Ons het die groot skoffel gebruik om die hardnekkige onkruid uit te grawe.
#  Ons dit groets kofel gebruik om die hartnekkige onkruid weet te groven.
# Vir vertaal- en tolkdoeleindes ontstaan daar nuwe velde waarvoor voorskrifte tans nie bestaan nie.
#  Vertaal in Toku du Eindes en stond daar nie vervelde waar voor vurschkriftetans nie bestaan nie.
# Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëernaalde oorgedra word.
#  dit kan onder meer optierig bruik van ongesterliseerde tatuairnolde oor gedroo word.
# Gooi asseblief al die rommel in die vullisblik.
#  Hoi aas het bleef al die Romo en die Phyllisblik.
# Die besoeke sal hoofsaaklik fokus op die versterking van bilaterale verhoudinge met albei lande.
#  Die besug is over zokkig volgens op die versterking van bilaterale vrouwdingen met albielanden.
# Hy sê vervalste goedere verlam die plaaslike vervaardigers in die klere- en die tekstielsektor.
#  Hij zei vervalstig goedere verland die plaslijke vervaardigers in die kleren in die tekstnieuwsektor.
# Die laaste aspek wat jy moet oorweeg, is betrokkenheid.
#  Die looste aspec wat die hem met woor ver, is bedrokkenheid.
# Ek het laasweek met ’n nuwe werk begin
#  Ek het last week met de nieuwe werk begin.

# %%
wer_metric = evaluate.load("wer")
overall_wer = wer_metric.compute(predictions=prediction, references=actual)

print(f"\n--- Evaluation Complete ---")
print(f"Evaluated on {len(prediction)} samples.")
print(f"Overall Word Error Rate (WER): {overall_wer:.4f}")
print(f"(Lower WER is better. 0 indicates perfect transcription.)")
# Out:
# --- Evaluation Complete ---
# Evaluated on 82 samples.
# Overall Word Error Rate (WER): 0.7031
# (Lower WER is better. 0 indicates perfect transcription.)

# %%
m4tv2_model_id = "facebook/seamless-m4t-v2-large"

# Determine the device and dtype
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float32 # SeamlessM4Tv2 is often used with float32

# Load the processor and model for SeamlessM4Tv2
processor_m4tv2 = AutoProcessor.from_pretrained(m4tv2_model_id)
model_m4tv2 = SeamlessM4Tv2ForSpeechToText.from_pretrained(m4tv2_model_id)

# Move the model to the appropriate device
model_m4tv2.to(device)

# Resample the audio data in the dataset to 16000 Hz to match the model's expected sampling rate
target_sampling_rate = 16000
cv_17 = cv_17.cast_column("audio", Audio(sampling_rate=target_sampling_rate))


prediction_m4tv2 = []
actual_m4tv2 = []

# Iterate through the dataset and perform transcription
for x in cv_17:
    # Access the audio data and sampling rate (now resampled)
    audio_array = x["audio"]["array"]
    sampling_rate = x["audio"]["sampling_rate"]

    # Process the audio input
    inputs = processor_m4tv2(
        audios=audio_array,
        sampling_rate=sampling_rate,
        return_tensors="pt",
        src_lang="afr"
    ).to(device)

    # Generate predictions using the model
    # Removed generate_speech=False as SeamlessM4Tv2ForSpeechToText does not support speech generation
    output_tokens = model_m4tv2.generate(**inputs, tgt_lang="afr")

    # Decode the predicted tokens back to text
    transcription = processor_m4tv2.batch_decode(output_tokens, skip_special_tokens=True)[0]

    # Append results to the lists
    prediction_m4tv2.append(transcription)
    actual_m4tv2.append(x["sentence"])

    # Print results for monitoring
    print(f"SeamlessM4Tv2 - Actual: {x['sentence']}")
    print(f"SeamlessM4Tv2 - Prediction: {transcription}")


# --- Evaluation for SeamlessM4Tv2 ---
# Assuming wer_metric is already loaded from the previous section
# import evaluate
# import jiwer
# wer_metric = evaluate.load("wer")

overall_wer_m4tv2 = wer_metric.compute(predictions=prediction_m4tv2, references=actual_m4tv2)

print(f"\n--- Evaluation Complete (Model: {m4tv2_model_id}) ---")
print(f"Evaluated on {len(prediction_m4tv2)} samples.")
print(f"Overall Word Error Rate (WER): {overall_wer_m4tv2:.4f}")
print(f"(Lower WER is better. 0 indicates perfect transcription.)")
# Out:
# preprocessor_config.json:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.7k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.17M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.34k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.72k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/211k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.24G [00:00<?, ?B/s]
# Instantiating a decoder SeamlessM4Tv2Attention without passing `layer_idx` is not recommended and will lead to errors during the forward call, if caching is used. Please make sure to provide a `layer_idx` when creating this class.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/9.91M [00:00<?, ?B/s]
# SeamlessM4Tv2 - Actual: Vertraging in die aanstelling van diensverskaffers maak dit moeilik om projekte betyds te voltooi.
# SeamlessM4Tv2 - Prediction: Vertraging in aanstelling van diensverskaffers maak dit moeilik om projekte betyds te voltooi
# SeamlessM4Tv2 - Actual: Wat doen hy?
# SeamlessM4Tv2 - Prediction: Wat is die doel?
# SeamlessM4Tv2 - Actual: Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
# SeamlessM4Tv2 - Prediction: Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
# SeamlessM4Tv2 - Actual: Taal is 'n belangrike instrument om begrip van menseregte en omgewingsgeregtigheid te ontwikkel.
# SeamlessM4Tv2 - Prediction: Taal is 'n belangrike instrument om begrip van menseregte en omgewingsgeregtigheid te ontwikkel
# SeamlessM4Tv2 - Actual: Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie?
# SeamlessM4Tv2 - Prediction: Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie
# SeamlessM4Tv2 - Actual: Ek het monumente gesien
# SeamlessM4Tv2 - Prediction: Ek het monumente gesien
# SeamlessM4Tv2 - Actual: Hulle het matte nodig gehad om die kaal vloer te bedek.
# SeamlessM4Tv2 - Prediction: Hulle het matte nodig gehad om die kaal vloer te bedek
# SeamlessM4Tv2 - Actual: Daar moet besef word dat die leeruitkomste saamwerk om leerders se taalvaardigheid te ontwikkel.
# SeamlessM4Tv2 - Prediction: Daar moet besef word dat die leerresultate saamwerk om leerders se taalvaardigheid te ontwikkel
# SeamlessM4Tv2 - Actual: Die leerder moet kennis dra van verskillende beroepsmoontlikhede en die implikasies van keuses.
# SeamlessM4Tv2 - Prediction: Die leerder moet kennis dra van verskillende beroepsmogelikhede en die implikasies van keuses
# SeamlessM4Tv2 - Actual: Skryf die persentasie Facebook-gebruikers neer wat met behulp van mobiele toestelle ingeteken het.
# SeamlessM4Tv2 - Prediction: Skryf die persentasie Facebook-gebruikers neer wat met bulk van mobiele toestelle ingeskryf het
# SeamlessM4Tv2 - Actual: Daar is kritiek dat Somali's geteister word wanneer hulle sake by die polisiestasie aanmeld.
# SeamlessM4Tv2 - Prediction: Daar is kritiek dat Somaliërs geteister word wanneer hulle sake by die polisistasie aanmeld
# SeamlessM4Tv2 - Actual: Hy is nie so groen dat ’n koei hom sal vreet nie
# SeamlessM4Tv2 - Prediction: Hy is nie so groen dat 'n koeie hom sal vreet nie
# SeamlessM4Tv2 - Actual: Die Program van Assessering vir Besigheidstudies bestaan uit sewe take wat intern geassesseer word.
# SeamlessM4Tv2 - Prediction: Die program van assosiering vir besigheidsstudies bestaan uit sewe take wat intern geassosieer word
# SeamlessM4Tv2 - Actual: Laai die vragmotor af.
# SeamlessM4Tv2 - Prediction: Laai die vragmotor af
# SeamlessM4Tv2 - Actual: In noodgevalle sal die mediese noodbeampte die pasiënt na die gepaste mediese fasiliteit vervoer.
# SeamlessM4Tv2 - Prediction: In noodgevalle sal die mediese noodbeampte die pasiënt na die gepaste mediese fasiliteit vervoer
# SeamlessM4Tv2 - Actual: Ek het vir ’n tyd Pools gestudeer
# SeamlessM4Tv2 - Prediction: Ek het vir 'n tyd Pools gestudeer
# SeamlessM4Tv2 - Actual: Daar is verskillende maniere om 'n argument- en 'n teenargument te struktureer.
# SeamlessM4Tv2 - Prediction: Daar is verskillende maniere om 'n argument en 'n teenargument te struktureer.
# SeamlessM4Tv2 - Actual: Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het.
# SeamlessM4Tv2 - Prediction: Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het
# SeamlessM4Tv2 - Actual: Die ingrypings is deel van die Program vir Grondhervorming en Geïntegreerde Steun vir Boere.
# SeamlessM4Tv2 - Prediction: Die ingrypings is deel van die program vir grondhervorming en geïntegreerde ondersteuning vir boere
# SeamlessM4Tv2 - Actual: Hy het baie struikelblokke teëgekom op pad om sy doelwitte te bereik.
# SeamlessM4Tv2 - Prediction: Hy het baie struikelblokke teëgekom op pad om Sy doelwitte te bereik
# SeamlessM4Tv2 - Actual: Vergeet van die verlede.
# SeamlessM4Tv2 - Prediction: Vergeet van die verlede
# SeamlessM4Tv2 - Actual: Informele of daaglikse assessering behels die daaglikse monitering van die leerders se vordering.
# SeamlessM4Tv2 - Prediction: Informeel of daaglikse assosiasie behels die daaglikse monitering van die leerders se vordering
# SeamlessM4Tv2 - Actual: Sy het gesteun toe sy die swaar pot oplig.
# SeamlessM4Tv2 - Prediction: Sy het gesteun toe Sy die swaar pot oplig
# SeamlessM4Tv2 - Actual: Alle biblioteke word deur die Landelike Biblioteekkonnektiwiteit-projek aan die Internet verbind.
# SeamlessM4Tv2 - Prediction: Alle biblioteke word deur die landelike biblioteekkonnektiwiteitsprojek aan die internet verbind.
# SeamlessM4Tv2 - Actual: Ek kannie môre praat nie
# SeamlessM4Tv2 - Prediction: Ek kan nie môre praat nie
# SeamlessM4Tv2 - Actual: Nou en dan las sy vrou ’n woord tussen.
# SeamlessM4Tv2 - Prediction: Nou en dan las Sy vrou 'n woord tussen
# SeamlessM4Tv2 - Actual: Is die inligting betroubaar?
# SeamlessM4Tv2 - Prediction: Is die inligting betroubaar
# SeamlessM4Tv2 - Actual: Die regering beskou ook marikultuur as belangrik omdat die mariene bronne aangevul moet word.
# SeamlessM4Tv2 - Prediction: Die regering beskou ook marienkultuur as belangrik omdat die mariene bronne aangevul moet word
# SeamlessM4Tv2 - Actual: Hierdie vennootskap het buitengewone positiewe resultate gelewer, wat verbruikers bevoordeel het.
# SeamlessM4Tv2 - Prediction: Hierdie vennootskap het buitengewoon positiewe resultate gelewer wat verbruikers bevoordeel het
# SeamlessM4Tv2 - Actual: Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word.
# SeamlessM4Tv2 - Prediction: Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word
# SeamlessM4Tv2 - Actual: Hy het sy kakebeen in 'n bakleiery gebreek.
# SeamlessM4Tv2 - Prediction: Hy het Sy kakebeen in 'n bakleiery gebreek
# SeamlessM4Tv2 - Actual: Die verkoopsyfers van twee motorvervaardigers in Suid-Afrika vir 'n sesmaande-tydperk is vrygestel.
# SeamlessM4Tv2 - Prediction: Die verkoopsyfers van twee motorvervaardigers in Suid-Afrika vir 'n ses maande tydperk is vrygestel
# SeamlessM4Tv2 - Actual: Ons gaan in die vakansie na 'n wildreservaat toe.
# SeamlessM4Tv2 - Prediction: Ons gaan hierdie vakansie na 'n wildreservaat toe
# SeamlessM4Tv2 - Actual: Wanneer is jou vrou se verjaarsdag?
# SeamlessM4Tv2 - Prediction: Wanneer is jou vryheidsdag?
# SeamlessM4Tv2 - Actual: Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande.
# SeamlessM4Tv2 - Prediction: Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande
# SeamlessM4Tv2 - Actual: Maak die leerders deurgaans van die gebruik van hoofletters, spasiëring en leestekens bewus.
# SeamlessM4Tv2 - Prediction: Maak die leerders deurgaans van die gebruik van hoofletters spasieering en leestekens bewus
# SeamlessM4Tv2 - Actual: Beskryf die tipe gesteente en onderliggende struktuur wat met dreineerpatroon C geassosieer word.
# SeamlessM4Tv2 - Prediction: Beskryf die tipe gesteente en onderliggende struktuur wat met trainerpatroon C geassosieer word.
# SeamlessM4Tv2 - Actual: My bejaarde buurvrou is 'n weduwee.
# SeamlessM4Tv2 - Prediction: My bejaarde buurvrou is 'n weduwee
# SeamlessM4Tv2 - Actual: Getal subsidies wat na naskoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf.
# SeamlessM4Tv2 - Prediction: Getal subsidies wat na na-skoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf
# SeamlessM4Tv2 - Actual: Ek kan beter asemhaal as die lug skoon is.
# SeamlessM4Tv2 - Prediction: Ek kan beter asemhaal as die lug skoon is
# SeamlessM4Tv2 - Actual: Ek eet dikwels smiddae vis
# SeamlessM4Tv2 - Prediction: Ek eet dikwels smiddo-vis
# SeamlessM4Tv2 - Actual: In Eendekuil het een deelnemer vir meer motorfietse vir patrollies in landelike gebiede gevra.
# SeamlessM4Tv2 - Prediction: In een dekade het een deelnemer vir meer motorfietse vir patrolle in landelike gebiede gevra
# SeamlessM4Tv2 - Actual: Energiebesparende busse word tans gebruik om mense na en van die besienswaardigheid te vervoer.
# SeamlessM4Tv2 - Prediction: Energiebesparende busse word tans gebruik om mense na en van die besigtigbaarheid te vervoer
# SeamlessM4Tv2 - Actual: Vergroot hierdie foto en sit dit op die muur.
# SeamlessM4Tv2 - Prediction: Vergroot hierdie foto en sit dit op die muur
# SeamlessM4Tv2 - Actual: Dit stel leerders in staat om sirkels en vierkante in verskillende posisies te identifiseer.
# SeamlessM4Tv2 - Prediction: Dit stel leerders in staat om sirkels en vierkante in verskillende posisies te identifiseer
# SeamlessM4Tv2 - Actual: Hy hou baie daarvan om sport te beoefen
# SeamlessM4Tv2 - Prediction: Hy hou baie daarvan om sport te beoefen
# SeamlessM4Tv2 - Actual: Hy geniet alkoholiese drankies, soos bier en wyn.
# SeamlessM4Tv2 - Prediction: Hy geniet alkoholiese drankies soos bier en wyn
# SeamlessM4Tv2 - Actual: Verbeterde funksionering van munisipale infrastruktuur en toegang tot basiese dienste aan inwoners.
# SeamlessM4Tv2 - Prediction: Verbeterde funksionering van munisipale infrastruktuur en toegang tot basiese dienste aan Inwoners
# SeamlessM4Tv2 - Actual: Dit is my broer
# SeamlessM4Tv2 - Prediction: Dit is my broer
# SeamlessM4Tv2 - Actual: Tweedens gee die gewigsaanduiding riglyne om die inhoud van assessering eweredig te versprei.
# SeamlessM4Tv2 - Prediction: Tweedens gee die gewigsaanwysing riglyne om die inhoud van assesserings eweredig te versprei.
# SeamlessM4Tv2 - Actual: Dis algaar dinge voor ons tyd, waarmee ons nou niks te doen het nie.
# SeamlessM4Tv2 - Prediction: Dis al gaar dinge voor ons tyd waarmee ons nou niks te doen het nie
# SeamlessM4Tv2 - Actual: Sodra hierdie hoërisikogesinne gestabiliseer is, sal die fokus na mediumrisikogevalle verskuif.
# SeamlessM4Tv2 - Prediction: Sodra hierdie hoë risikovlindings gestabiliseer is sal die fokus na medium risikovolle verskuif
# SeamlessM4Tv2 - Actual: Soos wat die wêreldbevolking gegroei het, het die aanvraag na stikstofryke kunsmis toegeneem.
# SeamlessM4Tv2 - Prediction: Soos wat die wêreldbevolking gegroei het het die aanvraag na stikstofryke kunsmis toegeneem
# SeamlessM4Tv2 - Actual: Hier las sy vrou ’n woordjie in en sê: “Julle moet verstaan".
# SeamlessM4Tv2 - Prediction: Hier lees Sy vrou 'n woordjie in en sê julle moet verstaan
# SeamlessM4Tv2 - Actual: Leer my asseblief hoe om naaldwerk te doen sodat ek klere kan maak.
# SeamlessM4Tv2 - Prediction: Leer my asseblief Hoe om naaldwerk te doen sodat ek klere kan maak
# SeamlessM4Tv2 - Actual: Nogtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat 'n Landswapen vereis.
# SeamlessM4Tv2 - Prediction: Nogtans behou dit duidelik die stabiliteit stemmigheid en dringendheid wat 'n landwapen vereis
# SeamlessM4Tv2 - Actual: Daar word vertrou dat alle belanghebbendes die inhoud as vernuwend en interessant sal ervaar.
# SeamlessM4Tv2 - Prediction: Daar word vertrou dat alle belanghebbendes die inhoud as vernuftig en interessant sal ervaar
# SeamlessM4Tv2 - Actual: Iemand die ore van die kop praat
# SeamlessM4Tv2 - Prediction: Iemand die ore van die kop praat
# SeamlessM4Tv2 - Actual: Wat het jy gisteraand vir aandete geëet?
# SeamlessM4Tv2 - Prediction: Wat het jy gisteraand vir aandete geëet
# SeamlessM4Tv2 - Actual: Gevolglik ontstaan genotipiese en fenotipiese verskille met verloop van tyd tussen die bevolkings.
# SeamlessM4Tv2 - Prediction: Gevolglik ontstaan genotipiese en fenotipiese verskille met die verloop van tyd tussen die bevolkings
# SeamlessM4Tv2 - Actual: Ons sal die bul kastreer as hy 'n jaar oud is.
# SeamlessM4Tv2 - Prediction: Ons sal die bul kastreer as Hy 'n jaar oud is
# SeamlessM4Tv2 - Actual: Skoonmaak- en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslewering te verseker.
# SeamlessM4Tv2 - Prediction: Skoonmaak en sekuriteitsdienste is uitkontrakteer om verbeterde dienslewering te verseker
# SeamlessM4Tv2 - Actual: Iemand in die rug steek
# SeamlessM4Tv2 - Prediction: Iemand in die rug steek
# SeamlessM4Tv2 - Actual: Kom ons kyk na die beginsels van verwysings.
# SeamlessM4Tv2 - Prediction: Kom ons kyk na die beginsels van verwysings
# SeamlessM4Tv2 - Actual: Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede.
# SeamlessM4Tv2 - Prediction: Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede
# SeamlessM4Tv2 - Actual: Ons moet nou aandete voorberei sodat dit betyds gereed is.
# SeamlessM4Tv2 - Prediction: Ons moet nou aandete voorberei sodat dit betyds gereed is
# SeamlessM4Tv2 - Actual: Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
# SeamlessM4Tv2 - Prediction: Die leerder verduidelik vaagweg Hoe improvisasie kan help in die voorbereiding van koreografie
# SeamlessM4Tv2 - Actual: Benoemings moet ingedien word deur die Amptelike Benoemingsvorm by hierdie Kennisgewing te gebruik.
# SeamlessM4Tv2 - Prediction: Benoemings moet ingedien word deur die amptelike benoemingsvorm by hierdie kennisgewing te gebruik
# SeamlessM4Tv2 - Actual: Hulle staan soggens vroeg op
# SeamlessM4Tv2 - Prediction: Hulle staan soggens vroeg op
# SeamlessM4Tv2 - Actual: Dit is 'n stil nag.
# SeamlessM4Tv2 - Prediction: Dit is 'n stil nag
# SeamlessM4Tv2 - Actual: Gebruik die gegewe inligting om 'n frekwensietabel van die verskillende dromme afval te teken.
# SeamlessM4Tv2 - Prediction: Gebruik die gegewe inligting om 'n frekwensie tabel van die verskillende drome af te teken
# SeamlessM4Tv2 - Actual: Haar wange is bloesend.
# SeamlessM4Tv2 - Prediction: Haar wang is blou.
# SeamlessM4Tv2 - Actual: Die kamer is leeg - daar is niemand daar nie.
# SeamlessM4Tv2 - Prediction: Die kamer is leeg daar is niemand daar nie
# SeamlessM4Tv2 - Actual: Dit ondersteun ook ekonomiese groei om die skep van broodnodige werksgeleenthede te bevorder.
# SeamlessM4Tv2 - Prediction: Dit ondersteun ook ekonomiese groei om die skepping van broodnodige werksgeleenthede te bevorder
# SeamlessM4Tv2 - Actual: Ons het die groot skoffel gebruik om die hardnekkige onkruid uit te grawe.
# SeamlessM4Tv2 - Prediction: Ons het die groot skuifel gebruik om die hardnekkige onkruid uit te grawe
# SeamlessM4Tv2 - Actual: Vir vertaal- en tolkdoeleindes ontstaan daar nuwe velde waarvoor voorskrifte tans nie bestaan nie.
# SeamlessM4Tv2 - Prediction: Vir taal en toldoeleindes ontstaan daar nuwe velde waarvoor voorskrifte tans nie bestaan nie
# SeamlessM4Tv2 - Actual: Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëernaalde oorgedra word.
# SeamlessM4Tv2 - Prediction: Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëermerke oorgedra word
# SeamlessM4Tv2 - Actual: Gooi asseblief al die rommel in die vullisblik.
# SeamlessM4Tv2 - Prediction: Gooi asseblief al die rommel in die vullisblik
# SeamlessM4Tv2 - Actual: Die besoeke sal hoofsaaklik fokus op die versterking van bilaterale verhoudinge met albei lande.
# SeamlessM4Tv2 - Prediction: Die besoeke sal hoofsaaklik fokus op die versterking van bilaterale verhoudings met albei lande
# SeamlessM4Tv2 - Actual: Hy sê vervalste goedere verlam die plaaslike vervaardigers in die klere- en die tekstielsektor.
# SeamlessM4Tv2 - Prediction: Hy sê vervalste goedere verlam die plaaslike vervaardigers in die klere en tekstielsektor
# SeamlessM4Tv2 - Actual: Die laaste aspek wat jy moet oorweeg, is betrokkenheid.
# SeamlessM4Tv2 - Prediction: Die laaste aspek wat jy moet oorweeg is betrokkenheid
# SeamlessM4Tv2 - Actual: Ek het laasweek met ’n nuwe werk begin
# SeamlessM4Tv2 - Prediction: Ek het laas week met 'n nuwe werk begin
#
# --- Evaluation Complete (Model: facebook/seamless-m4t-v2-large) ---
# Evaluated on 82 samples.
# Overall Word Error Rate (WER): 0.1922
# (Lower WER is better. 0 indicates perfect transcription.)

# %%
import openai
import tempfile
import soundfile as sf
import evaluate
from datasets import load_dataset, Audio

# Set your OpenAI API key
openai.api_key = "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"

cv_17Casted = cv_17.cast_column("audio", Audio(sampling_rate=16000))

# Load WER metric
wer_metric = evaluate.load("wer")

# Prepare lists to collect predictions and references
predictions = []
references = []

# Loop over the dataset
for sample in cv_17Casted:
    audio_array = sample["audio"]["array"]
    sample_rate = sample["audio"]["sampling_rate"]
    reference_text = sample["sentence"]

    # Save to a temporary .wav file
    with tempfile.NamedTemporaryFile(suffix=".wav") as temp_audio_file:
        sf.write(temp_audio_file.name, audio_array, samplerate=sample_rate)
        temp_audio_file.flush()

        # Transcribe using OpenAI Whisper or GPT-4o
        with open(temp_audio_file.name, "rb") as f:
            response = openai.audio.transcriptions.create(
                model="gpt-4o-transcribe",  # or "gpt-4o-transcribe" if available
                file=f,
                response_format="text",
                language="af"
            )

    transcription = response.strip()

    # Store results
    predictions.append(transcription)
    references.append(reference_text)

    # Optional: print each result
    print(f"Actual:      {reference_text}")
    print(f"Prediction:  {transcription}\n")

# Compute Word Error Rate
wer = wer_metric.compute(predictions=predictions, references=references)
print(f"\n--- OpenAI Transcription Evaluation ---")
print(f"Samples evaluated: {len(predictions)}")
print(f"Word Error Rate: {wer:.4f}")
# Out:
# Actual:      Vertraging in die aanstelling van diensverskaffers maak dit moeilik om projekte betyds te voltooi.
# Prediction:  Vertraging in aanstelling van diensverskaffers mag dit moeilik om projekte betyds te voltooi.
#
# Actual:      Wat doen hy?
# Prediction:  Wat doen hy?
#
# Actual:      Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
# Prediction:  Ons geniet altyd haar partytjies want sy is 'n uitstekende gasvrou.
#
# Actual:      Taal is 'n belangrike instrument om begrip van menseregte en omgewingsgeregtigheid te ontwikkel.
# Prediction:  Taal is 'n belangrike instrument om begrip van menseregte en opgewingsgeregtigheid te ontwikkel.
#
# Actual:      Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie?
# Prediction:  Watter van die volgende veiligheidsaspekte is nie die verantwoordelikheid van die werknemer nie?
#
# Actual:      Ek het monumente gesien
# Prediction:  Ek het monumente gesien.
#
# Actual:      Hulle het matte nodig gehad om die kaal vloer te bedek.
# Prediction:  Hulle het matte nodig gehad om die kaal vloer te bedek.
#
# Actual:      Daar moet besef word dat die leeruitkomste saamwerk om leerders se taalvaardigheid te ontwikkel.
# Prediction:  Daar moet byvoorbeeld daaroor geleer uitkomste saamwerk om leerders se taalvaardigheid te ontwikkel.
#
# Actual:      Die leerder moet kennis dra van verskillende beroepsmoontlikhede en die implikasies van keuses.
# Prediction:  Die lere moet kennis dra van verskillende beroepsmoontlikhede en die implikasies van keuses.
#
# Actual:      Skryf die persentasie Facebook-gebruikers neer wat met behulp van mobiele toestelle ingeteken het.
# Prediction:  Skryf die persentasie Facebook-gebruikers neer wat met behulp van mobiele toestelle ingeteken het.
#
# Actual:      Daar is kritiek dat Somali's geteister word wanneer hulle sake by die polisiestasie aanmeld.
# Prediction:  Daar is kritiek dat Zuma alies getuisde word wanneer klagtes by die polisie stasie aangemeld.
#
# Actual:      Hy is nie so groen dat ’n koei hom sal vreet nie
# Prediction:  Hy is nie so groen dat ek hom sal vreet nie.
#
# Actual:      Die Program van Assessering vir Besigheidstudies bestaan uit sewe take wat intern geassesseer word.
# Prediction:  Die program van assessering vir besigheidstudies bestaan uit sewe take wat intern geassesseer word.
#
# Actual:      Laai die vragmotor af.
# Prediction:  Nou die vraagmoord daarop.
#
# Actual:      In noodgevalle sal die mediese noodbeampte die pasiënt na die gepaste mediese fasiliteit vervoer.
# Prediction:  In noodgevalle sal die mediese nootbeampte die pasiënt na die gepaste mediese fasiliteit vervoer.
#
# Actual:      Ek het vir ’n tyd Pools gestudeer
# Prediction:  Ek het vir 'n tyd Pools gestudeer.
#
# Actual:      Daar is verskillende maniere om 'n argument- en 'n teenargument te struktureer.
# Prediction:  Daar is verskillende maniere om 'n argument en 'n teenargument te struktureer.
#
# Actual:      Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het.
# Prediction:  Verduidelik waarom Hitler die vernietiging van die Jode as die belangrikste taak beskou het.
#
# Actual:      Die ingrypings is deel van die Program vir Grondhervorming en Geïntegreerde Steun vir Boere.
# Prediction:  Die ingrypings is deel van die program vir grondhervorming en geïntegreerde steun vir boere.
#
# Actual:      Hy het baie struikelblokke teëgekom op pad om sy doelwitte te bereik.
# Prediction:  Hy het baie struikelblokke teëgekom op pad om sy doelwitte te bereik.
#
# Actual:      Vergeet van die verlede.
# Prediction:  Vergeet van die verlede.
#
# Actual:      Informele of daaglikse assessering behels die daaglikse monitering van die leerders se vordering.
# Prediction:  Informele of daaglikse assesering behalwe die daaglikse monitering van die leerders se vordering.
#
# Actual:      Sy het gesteun toe sy die swaar pot oplig.
# Prediction:  Sy het gesterf toe sy die swaar pot oplig.
#
# Actual:      Alle biblioteke word deur die Landelike Biblioteekkonnektiwiteit-projek aan die Internet verbind.
# Prediction:  Alle biblioteke word deur Ierland se Biblioteek Konnektiwiteitprojek aan die internet verbind.
#
# Actual:      Ek kannie môre praat nie
# Prediction:  Ek kan nie môre praat nie.
#
# Actual:      Nou en dan las sy vrou ’n woord tussen.
# Prediction:  Nou en dan las sy vrou 'n woord tussen.
#
# Actual:      Is die inligting betroubaar?
# Prediction:  Is die inligting betroubaar?
#
# Actual:      Die regering beskou ook marikultuur as belangrik omdat die mariene bronne aangevul moet word.
# Prediction:  Die regering beskou ook mariene kultuur as belangrik omdat die mariene bronne aangevul moet word.
#
# Actual:      Hierdie vennootskap het buitengewone positiewe resultate gelewer, wat verbruikers bevoordeel het.
# Prediction:  Hierdie vennootskap het buitengewone positiewe resultate gelewer, wat verbruikers bevoordeel het.
#
# Actual:      Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word.
# Prediction:  Die eienskappe van elke vorm word aangeleer voordat vergelykings tussen vorms bespreek kan word.
#
# Actual:      Hy het sy kakebeen in 'n bakleiery gebreek.
# Prediction:  Hy het sy kalfgebene in 'n bakleiery gebreek.
#
# Actual:      Die verkoopsyfers van twee motorvervaardigers in Suid-Afrika vir 'n sesmaande-tydperk is vrygestel.
# Prediction:  Die verkoopsyfers van twee moddervulvaarigers is uit avergegaan en vir 'n ses maande tydperk is vrygestel.
#
# Actual:      Ons gaan in die vakansie na 'n wildreservaat toe.
# Prediction:  Ons gaan met vakansie na 'n wildreservaat toe.
#
# Actual:      Wanneer is jou vrou se verjaarsdag?
# Prediction:  Wanneer is jou vrou se verjaarsdag?
#
# Actual:      Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande.
# Prediction:  Beplanning is 'n dinamiese proses wat voorsiening maak vir aanpassing as gevolg van toestande.
#
# Actual:      Maak die leerders deurgaans van die gebruik van hoofletters, spasiëring en leestekens bewus.
# Prediction:  Maak die leerders deurlopend van die gebruik van hoofletters, spasiëring en leestekens bewus.
#
# Actual:      Beskryf die tipe gesteente en onderliggende struktuur wat met dreineerpatroon C geassosieer word.
# Prediction:  Beskryf die tipe gesteente en onderliggende struktuur wat met reënneerpatroon C geassosieer word.
#
# Actual:      My bejaarde buurvrou is 'n weduwee.
# Prediction:  My bejaarde buurvrou is 'n weduwee.
#
# Actual:      Getal subsidies wat na naskoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf.
# Prediction:  Getal subsidies wat na naskoolse sorgfasiliteite oorgedra is om dienste aan kinders te verskaf.
#
# Actual:      Ek kan beter asemhaal as die lug skoon is.
# Prediction:  Ek kan beter asemhaal as die lug skoon is.
#
# Actual:      Ek eet dikwels smiddae vis
# Prediction:  Ek eet dikwels smiddae vis.
#
# Actual:      In Eendekuil het een deelnemer vir meer motorfietse vir patrollies in landelike gebiede gevra.
# Prediction:  In een dekuil het een deelnemer vermeer motorfietse vir patrollies in landelike gebiede gevra.
#
# Actual:      Energiebesparende busse word tans gebruik om mense na en van die besienswaardigheid te vervoer.
# Prediction:  Energiebesparende busse word tans gebruik om mense na en van die besienswaardigheid te vervoer.
#
# Actual:      Vergroot hierdie foto en sit dit op die muur.
# Prediction:  Vergroot eerder die foto en sit dit op jou muur.
#
# Actual:      Dit stel leerders in staat om sirkels en vierkante in verskillende posisies te identifiseer.
# Prediction:  Dit stel leerders in staat om sirkel en vierkante in verskillende posisies te identifiseer.
#
# Actual:      Hy hou baie daarvan om sport te beoefen
# Prediction:  Hulle hou baie daarvan om sport te beoefen.
#
# Actual:      Hy geniet alkoholiese drankies, soos bier en wyn.
# Prediction:  Hy geniet alkoholiese drankies soos bier en wyn.
#
# Actual:      Verbeterde funksionering van munisipale infrastruktuur en toegang tot basiese dienste aan inwoners.
# Prediction:  Verbeter die funksionering van munisipale infrastrukture en toegang tot basiese dienste aan inwoners.
#
# Actual:      Dit is my broer
# Prediction:  Dit is my broer.
#
# Actual:      Tweedens gee die gewigsaanduiding riglyne om die inhoud van assessering eweredig te versprei.
# Prediction:  Tweedens gee die gewigsaanduiding riglyne om die inhoud van assosiering eweredig te versprei.
#
# Actual:      Dis algaar dinge voor ons tyd, waarmee ons nou niks te doen het nie.
# Prediction:  Dis al gaarde dinge voor ons tyd, waarmee ons nou niks te doen het nie.
#
# Actual:      Sodra hierdie hoërisikogesinne gestabiliseer is, sal die fokus na mediumrisikogevalle verskuif.
# Prediction:  Sodra hierdie hoë risiko gesinne gevestig is, sal die fokus na medium-risiko gevalle verskuif.
#
# Actual:      Soos wat die wêreldbevolking gegroei het, het die aanvraag na stikstofryke kunsmis toegeneem.
# Prediction:  Soos wat die wêreldbevolking gegroei het, het die aanvraag na stikstofryke kunsmis toegeneem.
#
# Actual:      Hier las sy vrou ’n woordjie in en sê: “Julle moet verstaan".
# Prediction:  Hier las sy vroue voor wieki en en sê: 'Julle moet verstaan!'
#
# Actual:      Leer my asseblief hoe om naaldwerk te doen sodat ek klere kan maak.
# Prediction:  Leer my asseblief hoe om naaldwerk te doen sodat ek klere kan maak.
#
# Actual:      Nogtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat 'n Landswapen vereis.
# Prediction:  Nogtans behou dit duidelik die stabiliteit, stemmigheid en dringendheid wat 'n landswapen vereis.
#
# Actual:      Daar word vertrou dat alle belanghebbendes die inhoud as vernuwend en interessant sal ervaar.
# Prediction:  Daar word vertrou dat alle belanghebbendes die inhoud as vernuwend en interessant sal ervaar.
#
# Actual:      Iemand die ore van die kop praat
# Prediction:  Iemand die ore van die kop praat.
#
# Actual:      Wat het jy gisteraand vir aandete geëet?
# Prediction:  Wat het jy gisteraand vir aandete geëet?
#
# Actual:      Gevolglik ontstaan genotipiese en fenotipiese verskille met verloop van tyd tussen die bevolkings.
# Prediction:  Gevolglik ontstaan genotipiese en fenotipiese verskille met die verloop van tyd tussen die bevolkings.
#
# Actual:      Ons sal die bul kastreer as hy 'n jaar oud is.
# Prediction:  Onsal die bul kastrêr as hy 'n jaar oud is.
#
# Actual:      Skoonmaak- en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslewering te verseker.
# Prediction:  Skoonmaak- en sekuriteitsdienste is uitgekontrakteer om verbeterde dienslewering te verseker.
#
# Actual:      Iemand in die rug steek
# Prediction:  Iemand in die rug steek.
#
# Actual:      Kom ons kyk na die beginsels van verwysings.
# Prediction:  Komo kyk na die beperkings van verwysings.
#
# Actual:      Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede.
# Prediction:  Armoede is die duidelikste sigbaar in landelike gebiede weens die gebrek aan werksgeleenthede.
#
# Actual:      Ons moet nou aandete voorberei sodat dit betyds gereed is.
# Prediction:  Asb. dit nou antieke voorberei sodat dit betyds gereed is.
#
# Actual:      Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
# Prediction:  Die leerder verduidelik vaagweg hoe improvisering kan help in die voorbereiding van choreografie.
#
# Actual:      Benoemings moet ingedien word deur die Amptelike Benoemingsvorm by hierdie Kennisgewing te gebruik.
# Prediction:  Benoemings moet ingedien word deur die amptelike benoemingsvorm by hierdie kennisgewing te gebruik.
#
# Actual:      Hulle staan soggens vroeg op
# Prediction:  Hulle staan soggens vroeg op.
#
# Actual:      Dit is 'n stil nag.
# Prediction:  Dit is 'n stownag.
#
# Actual:      Gebruik die gegewe inligting om 'n frekwensietabel van die verskillende dromme afval te teken.
# Prediction:  Gebruik die gegewe inligting om 'n frekwensietabel van die verskillende drome afval te teken.
#
# Actual:      Haar wange is bloesend.
# Prediction:  Haar wange is bloosend.
#
# Actual:      Die kamer is leeg - daar is niemand daar nie.
# Prediction:  Die kamer is leeg, daar is niemand daar nie.
#
# Actual:      Dit ondersteun ook ekonomiese groei om die skep van broodnodige werksgeleenthede te bevorder.
# Prediction:  Dit ondersteun ook ekonomiese groei om die skepping van broodnodige werksgeleenthede te bevorder.
#
# Actual:      Ons het die groot skoffel gebruik om die hardnekkige onkruid uit te grawe.
# Prediction:  Ons het ‘n groot skopvel gebruik om die hardnekkige onkruid uit te grawe.
#
# Actual:      Vir vertaal- en tolkdoeleindes ontstaan daar nuwe velde waarvoor voorskrifte tans nie bestaan nie.
# Prediction:  Vertaal en tolkgedoentes ontstaan daar nuwe velde waarvoor voorskifte tans nie bestaan nie.
#
# Actual:      Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëernaalde oorgedra word.
# Prediction:  Dit kan onder meer ook deur die gebruik van ongesteriliseerde tatoeëernaalde oorgedra word.
#
# Actual:      Gooi asseblief al die rommel in die vullisblik.
# Prediction:  Gooi asseblief al die rommel in die vullisblik.
#
# Actual:      Die besoeke sal hoofsaaklik fokus op die versterking van bilaterale verhoudinge met albei lande.
# Prediction:  Die besoekers sal hoofsaaklik fokus op die versterking van bilaterale verhoudinge met albei lande.
#
# Actual:      Hy sê vervalste goedere verlam die plaaslike vervaardigers in die klere- en die tekstielsektor.
# Prediction:  Hy sê veralstig goedere verlamp die plaaslike vervaardigers in die klere- en tekstielsektor.
#
# Actual:      Die laaste aspek wat jy moet oorweeg, is betrokkenheid.
# Prediction:  Die laaste aspek wat hiermee oorweeg, is betrokkenheid.
#
# Actual:      Ek het laasweek met ’n nuwe werk begin
# Prediction:  Ek het laas week met die nuwe werk begin.
#
#
# --- OpenAI Transcription Evaluation ---
# Samples evaluated: 82
# Word Error Rate: 0.1542
